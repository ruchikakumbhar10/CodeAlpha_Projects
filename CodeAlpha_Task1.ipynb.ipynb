# %% [markdown]
# ## CodeAlpha TASK 1

# %% [markdown]
# ## WEB SCRAPING

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Base URL
url = 'http://quotes.toscrape.com/'
url
# Out:
# 'http://quotes.toscrape.com/'

# %%
# Send request to website
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
# Store all data in a list
data = []

# Extract quotes, authors, and tags
quotes = soup.find_all('div', class_='quote')

for quote in quotes:
    text = quote.find('span', class_='text').text
    author = quote.find('small', class_='author').text
    tags = [tag.text for tag in quote.find_all('a', class_='tag')]
    data.append({
        'Quote': text,
        'Author': author,
        'Tags': ', '.join(tags)
    })

# %%
# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#                                                Quote             Author  \
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. I've just found 10,000 way...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin
#
#                                            Tags
# 0        change, deep-thoughts, thinking, world
# 1                            abilities, choices
# ...

# %%
# Show preview
print(df.head())
# Out:
#                                                Quote           Author  \
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe
#
#                                            Tags
# 0        change, deep-thoughts, thinking, world
# 1                            abilities, choices
# 2  inspirational, life, live, miracle, miracles
# 3              aliteracy, books, classic, humor
# 4                    be-yourself, inspirational

# %%
# Save to CSV
df.to_csv('scraped_quotes.csv', index=False)
print("Data saved to scraped_quotes.csv")
# Out:
# Data saved to scraped_quotes.csv

# %% [markdown]
# ## Insights

# %% [markdown]
# 1. A total of 100 quotes were scraped from the website, spanning across multiple pages using BeautifulSoup.

# %% [markdown]
# 2. The Dataset includes quotes from 50 unique authors, showcasing a diverse range of literary voices.

# %% [markdown]
# 3. The most quoted author in the dataset is Albert Einstein, with 10 quotes, making up 10% of the entire dataset.

# %% [markdown]
# 4.The tag 'inspirational' appeared 24 times, making it the most frequently associated theme across all quotes.

# %% [markdown]
# 5. On average, each quote contains 106 characters, with the longest quote being 267 characters and the shortest just 36 characters long.
